# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
list(df)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df["Name"])
# Out:
# pandas.core.series.Series

# %%
df[["Name","Pclass"]]
# Out:
#                                                   Name  Pclass
# 0                              Braund, Mr. Owen Harris       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2                               Heikkinen, Miss. Laina       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4                             Allen, Mr. William Henry       3
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas       2
# 887                       Graham, Miss. Margaret Edith       1
# 888           Johnston, Miss. Catherine Helen "Carrie"       3
# 889                              Behr, Mr. Karl Howell       1
# 890                                Dooley, Mr. Patrick       3
#
# [891 rows x 2 columns]

# %%
type([["Name","Pclass"]])
# Out:
# list

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df1 =pd.read_excel("LUSID Excel - Setting up your market data.xlsx")

# %%
df1.head(5)
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
#                                           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                 Datetimes in LUSID        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3   This sheet allows you to format datetimes for...        NaN        NaN
# 4        If you have any questions please visit our:        NaN        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0         NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN
# ...

# %%
df2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df2)
# Out:
# list

# %%
len(df2)
# Out:
# 1

# %%
df2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df3 = df2[0]

# %%
df3.head(2)
# Out:
#   Rk        Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT% ORB  DRB  \
# 0  1    Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784  79  222
# 1  2  Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609   9   19
#
#    TRB AST STL BLK TOV   PF  PTS
# 0  301  68  27  22  60  147  398
# 1   28  16  16   7  14   24   94
#
# [2 rows x 30 columns]

# %%
df3.dtypes[0:4]
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# dtype: object

# %% [markdown]
# ### end

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1 = df[["Name","Fare","Survived","Pclass"]]

# %%
df1.head()
# Out:
#                                                 Name     Fare  Survived  \
# 0                            Braund, Mr. Owen Harris   7.2500         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833         1
# 2                             Heikkinen, Miss. Laina   7.9250         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000         1
# 4                           Allen, Mr. William Henry   8.0500         0
#
#    Pclass
# 0       3
# 1       1
# 2       3
# 3       1
# 4       3

# %%
df.dtypes == object
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == object].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == object].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == object].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df[df.dtypes[df.dtypes == float].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df['new_col'] = 0

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col
# 0      0  A/5 21171   7.2500   NaN        S        0
# 1      0   PC 17599  71.2833   C85        C        0

# %%
df["new_col2"]= df['Pclass']*df['Fare']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#                                                   Name     Fare  Survived  \
# 0                              Braund, Mr. Owen Harris   7.2500         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833         1
# 2                               Heikkinen, Miss. Laina   7.9250         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000         1
# 4                             Allen, Mr. William Henry   8.0500         0
# ..                                                 ...      ...       ...
# 886                              Montvila, Rev. Juozas  13.0000         0
# 887                       Graham, Miss. Margaret Edith  30.0000         1
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500         0
# 889                              Behr, Mr. Karl Howell  30.0000         1
# 890                                Dooley, Mr. Patrick   7.7500         0
#
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# ...

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
type(df["Pclass"])
# Out:
# pandas.core.series.Series

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df1.head()
# Out:
#                                                 Name     Fare  Survived  \
# 0                            Braund, Mr. Owen Harris   7.2500         0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833         1
# 2                             Heikkinen, Miss. Laina   7.9250         1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000         1
# 4                           Allen, Mr. William Henry   8.0500         0
#
#    Pclass
# 0       3
# 1       1
# 2       3
# 3       1
# 4       3

# %%
fare_mean = df["Fare"].mean()

# %%
df1[df1["Fare"]>fare_mean]
# Out:
#                                                   Name      Fare  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000         1
# 6                              McCarthy, Mr. Timothy J   51.8625         0
# 23                        Sloper, Mr. William Thompson   35.5000         1
# 27                      Fortune, Mr. Charles Alexander  263.0000         0
# ..                                                 ...       ...       ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  164.8667         1
# 863                  Sage, Miss. Dorothy Edith "Dolly"   69.5500         0
# 867               Roebling, Mr. Washington Augustus II   50.4958         0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   52.5542         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   83.1583         1
#
#      Pclass
# 1         1
# 3         1
# 6         1
# 23        1
# ...

# %%
df1[df1["Fare"]==0]
# Out:
#                                  Name  Fare  Survived  Pclass
# 179               Leonard, Mr. Lionel   0.0         0       3
# 263             Harrison, Mr. William   0.0         0       1
# 271      Tornquist, Mr. William Henry   0.0         1       3
# 277       Parkes, Mr. Francis "Frank"   0.0         0       2
# 302   Johnson, Mr. William Cahoone Jr   0.0         0       3
# 413    Cunningham, Mr. Alfred Fleming   0.0         0       2
# 466             Campbell, Mr. William   0.0         0       2
# 481  Frost, Mr. Anthony Wood "Archie"   0.0         0       2
# 597               Johnson, Mr. Alfred   0.0         0       3
# 633     Parr, Mr. William Henry Marsh   0.0         0       1
# 674        Watson, Mr. Ennis Hastings   0.0         0       2
# 732              Knight, Mr. Robert J   0.0         0       2
# 806            Andrews, Mr. Thomas Jr   0.0         0       1
# 815                  Fry, Mr. Richard   0.0         0       1
# ...

# %%
df1[df1["Fare"]==max(df1["Fare"])]
# Out:
#                                    Name      Fare  Survived  Pclass
# 258                    Ward, Miss. Anna  512.3292         1       1
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292         1       1
# 737              Lesurer, Mr. Gustave J  512.3292         1       1

# %%
a = df1[df1["Fare"]>fare_mean]

# %%
len(a)
# Out:
# 211

# %%
b = df1[df1["Fare"]<fare_mean]

# %%
len(b)
# Out:
# 680

# %%
len(df)
# Out:
# 891

# %%
df1[(df1["Fare"]>fare_mean) & (df1["Survived"]==1)]
# Out:
#                                                   Name      Fare  Survived  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   71.2833         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)   53.1000         1
# 23                        Sloper, Mr. William Thompson   35.5000         1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  146.5208         1
# 43            Laroche, Miss. Simonne Marie Anne Andree   41.5792         1
# ..                                                 ...       ...       ...
# 849       Goldenberg, Mrs. Samuel L (Edwiga Grabowska)   89.1042         1
# 853                          Lines, Miss. Mary Conover   39.4000         1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  164.8667         1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)   52.5542         1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)   83.1583         1
#
#      Pclass
# 1         1
# 3         1
# 23        1
# 31        1
# ...

# %%
len(df1[(df1["Fare"]>fare_mean) & (df1["Survived"]==1)])
# Out:
# 126

# %%
df1[(df1["Fare"]<fare_mean) & (df1["Survived"]==1)]
# Out:
#                                                   Name     Fare  Survived  \
# 2                               Heikkinen, Miss. Laina   7.9250         1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333         1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  30.0708         1
# 10                     Sandstrom, Miss. Marguerite Rut  16.7000         1
# 11                            Bonnell, Miss. Elizabeth  26.5500         1
# ..                                                 ...      ...       ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  24.0000         1
# 875                   Najib, Miss. Adele Kiamie "Jane"   7.2250         1
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  26.0000         1
# 887                       Graham, Miss. Margaret Edith  30.0000         1
# 889                              Behr, Mr. Karl Howell  30.0000         1
#
#      Pclass
# 2         3
# 8         3
# 9         2
# 10        3
# ...

# %%
len(df1[(df1["Fare"]<fare_mean) & (df1["Survived"]==1)]["Name"])
# Out:
# 216

# %%
servival_percentage_of_rich = (126/211)*100

# %%
servival_percentage_of_rich
# Out:
# 59.71563981042654

# %%
servival_percentage_of_poor = (216/680)*100

# %%
servival_percentage_of_poor
# Out:
# 31.76470588235294

# %%
df[(df['Sex'] == 'felmale')  | (df['Fare'] > 32 )]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### & is used for 'and',  | is used for 'or'

# %%
df[(df['Sex'] == 'male')  & (df['Fare'] > 32 )]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
df[0:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col  new_col2
# 0      0         A/5 21171   7.2500   NaN        S        0   21.7500
# 1      0          PC 17599  71.2833   C85        C        0   71.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S        0   23.7750
# ...

# %%
df[0::5]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 5              6         0       3
# 10            11         1       3
# 15            16         1       2
# 20            21         0       2
# ..           ...       ...     ...
# 870          871         0       3
# 875          876         1       3
# 880          881         1       2
# 885          886         0       3
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 10                Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# ...

# %%
df[['Name','PassengerId',"Fare",'Cabin']][0:5]
# Out:
#                                                 Name  PassengerId     Fare  \
# 0                            Braund, Mr. Owen Harris            1   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2  71.2833
# 2                             Heikkinen, Miss. Laina            3   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4  53.1000
# 4                           Allen, Mr. William Henry            5   8.0500
#
#   Cabin
# 0   NaN
# 1   C85
# 2   NaN
# 3  C123
# 4   NaN

# %%
df.iloc[0:5,[4,2,3]]
# Out:
#       Sex  Pclass                                               Name
# 0    male       3                            Braund, Mr. Owen Harris
# 1  female       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  female       3                             Heikkinen, Miss. Laina
# 3  female       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    male       3                           Allen, Mr. William Henry

# %%
df.loc[0:5,["Name","Pclass","Fare"]]
# Out:
#                                                 Name  Pclass     Fare
# 0                            Braund, Mr. Owen Harris       3   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  71.2833
# 2                             Heikkinen, Miss. Laina       3   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  53.1000
# 4                           Allen, Mr. William Henry       3   8.0500
# 5                                   Moran, Mr. James       3   8.4583

# %% [markdown]
# # pandas part 2

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
s = df["Name"][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s[1]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
l = ['a','b','c','d','e','f','g','h','i','j']

# %%
s1 = pd.Series(list(s),index = l)

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s.append(s1)
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\137217768.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s.append(s1)
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# ...

# %%
a1 = pd.Series(["Aditya",'Ram','Shankar',"mannat"],index=[1,2,3,4])

# %%
a2 = pd.Series(["jiya",'elvish','pooja',"Sam"],index=[6,4,8,9])

# %%
a3 =a1.append(a2)
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\3347893063.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a3 =a1.append(a2)

# %%
a1[4]
# Out:
# 'mannat'

# %%
a3[4]
# Out:
# 4    mannat
# 4    elvish
# dtype: object

# %%
a3[0:3]
# Out:
# 1     Aditya
# 2        Ram
# 3    Shankar
# dtype: object

# %%
a3[0:4]
# Out:
# 1     Aditya
# 2        Ram
# 3    Shankar
# 4     mannat
# dtype: object

# %%
a1+a2
# Out:
# 1             NaN
# 2             NaN
# 3             NaN
# 4    mannatelvish
# 6             NaN
# 8             NaN
# 9             NaN
# dtype: object

# %% [markdown]
# #THE multiplication can be done if a1 and a2 both are integer

# %% [markdown]
# ## Change of the topic

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop("PassengerId",axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ##### To delete permanently

# %%
df.drop("PassengerId",axis = 1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.set_index("Name",inplace=True)

# %%
df
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
d= {'key1':[1,2,3,4,5],
  'key2':[3,4,5,6,7],
  'key3':[1,2,3,6,7]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     3     1
# 1     2     4     2
# 2     3     5     3
# 3     4     6     6
# 4     5     7     7

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df1.dropna(inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1.dropna(axis=1,inplace=True)

# %%
df1
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %%
df1 = pd.read_csv("taxonomy.csv.xls")

# %%
df1.fillna('Aditya')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency    Aditya                Aditya
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
S = df.groupby('Survived')

# %%
S.mean()
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\3310079792.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   S.mean()
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
S.sum()
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\1450114867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   S.sum()
#           Pclass       Age  SibSp  Parch        Fare
# Survived
# 0           1390  12985.50    304    181  12142.7199
# 1            667   8219.67    162    159  16551.2294

# %%
G = df.groupby('Pclass')

# %%
G.sum()
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\3958047458.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   G.sum()
#         Survived      Age  SibSp  Parch        Fare
# Pclass
# 1            136  7111.42     90     77  18177.4125
# 2             87  5168.83     74     70   3801.8417
# 3            119  8924.92    302    193   6714.6951

# %%
G.sum().T
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\1826090826.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   G.sum().T
# Pclass             1          2          3
# Survived    136.0000    87.0000   119.0000
# Age        7111.4200  5168.8300  8924.9200
# SibSp        90.0000    74.0000   302.0000
# Parch        77.0000    70.0000   193.0000
# Fare      18177.4125  3801.8417  6714.6951

# %%
S.max().T
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\3943461749.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   S.max().T
# Survived                            0                        1
# Name      van Melkebeke, Mr. Philemon  de Mulder, Mr. Theodore
# Pclass                              3                        3
# Sex                              male                     male
# Age                              74.0                     80.0
# SibSp                               8                        4
# Parch                               6                        5
# Ticket                      WE/P 5735                WE/P 5735
# Fare                            263.0                 512.3292

# %%
S.max().transpose()
# Out:
# C:\Users\adipa\AppData\Local\Temp\ipykernel_13904\1018733767.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   S.max().transpose()
# Survived                            0                        1
# Name      van Melkebeke, Mr. Philemon  de Mulder, Mr. Theodore
# Pclass                              3                        3
# Sex                              male                     male
# Age                              74.0                     80.0
# SibSp                               8                        4
# Parch                               6                        5
# Ticket                      WE/P 5735                WE/P 5735
# Fare                            263.0                 512.3292

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df5 = df[['Name','Survived','Fare']][10:17]

# %%
df6 = df[['Name','Survived','Fare']][15:23]

# %%
df5
# Out:
#                                     Name  Survived     Fare
# 10       Sandstrom, Miss. Marguerite Rut         1  16.7000
# 11              Bonnell, Miss. Elizabeth         1  26.5500
# 12        Saundercock, Mr. William Henry         0   8.0500
# 13           Andersson, Mr. Anders Johan         0  31.2750
# 14  Vestrom, Miss. Hulda Amanda Adolfina         0   7.8542
# 15      Hewlett, Mrs. (Mary D Kingcome)          1  16.0000
# 16                  Rice, Master. Eugene         0  29.1250

# %%
df6
# Out:
#                                                  Name  Survived     Fare
# 15                   Hewlett, Mrs. (Mary D Kingcome)          1  16.0000
# 16                               Rice, Master. Eugene         0  29.1250
# 17                       Williams, Mr. Charles Eugene         1  13.0000
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...         0  18.0000
# 19                            Masselmani, Mrs. Fatima         1   7.2250
# 20                               Fynney, Mr. Joseph J         0  26.0000
# 21                              Beesley, Mr. Lawrence         1  13.0000
# 22                        McGowan, Miss. Anna "Annie"         1   8.0292

# %%
pd.concat([df5,df6])
# Out:
#                                                  Name  Survived     Fare
# 10                    Sandstrom, Miss. Marguerite Rut         1  16.7000
# 11                           Bonnell, Miss. Elizabeth         1  26.5500
# 12                     Saundercock, Mr. William Henry         0   8.0500
# 13                        Andersson, Mr. Anders Johan         0  31.2750
# 14               Vestrom, Miss. Hulda Amanda Adolfina         0   7.8542
# 15                   Hewlett, Mrs. (Mary D Kingcome)          1  16.0000
# 16                               Rice, Master. Eugene         0  29.1250
# 15                   Hewlett, Mrs. (Mary D Kingcome)          1  16.0000
# 16                               Rice, Master. Eugene         0  29.1250
# 17                       Williams, Mr. Charles Eugene         1  13.0000
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...         0  18.0000
# 19                            Masselmani, Mrs. Fatima         1   7.2250
# ...

# %%
df7 =pd.concat([df5,df6],axis=1)

# %%
df7.fillna('Aditya')
# Out:
#                                     Name Survived    Fare  \
# 10       Sandstrom, Miss. Marguerite Rut      1.0    16.7
# 11              Bonnell, Miss. Elizabeth      1.0   26.55
# 12        Saundercock, Mr. William Henry      0.0    8.05
# 13           Andersson, Mr. Anders Johan      0.0  31.275
# 14  Vestrom, Miss. Hulda Amanda Adolfina      0.0  7.8542
# 15      Hewlett, Mrs. (Mary D Kingcome)       1.0    16.0
# 16                  Rice, Master. Eugene      0.0  29.125
# 17                                Aditya   Aditya  Aditya
# 18                                Aditya   Aditya  Aditya
# 19                                Aditya   Aditya  Aditya
# 20                                Aditya   Aditya  Aditya
# 21                                Aditya   Aditya  Aditya
# 22                                Aditya   Aditya  Aditya
#
#                                                  Name Survived    Fare
# 10                                             Aditya   Aditya  Aditya
# ...

# %%
data1 = pd.DataFrame({'key1':[1,2,3,4,5],
        'key2':[4,5,6,7,8],
        'key3':[3,5,3,5,6]})

# %%
data2 = pd.DataFrame({'key1':[1,3,7,6,5],
        'key4':[33,4,43,45,6],
        'key5':[8,7,8,6,7]})

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     5
# 2     3     6     3
# 3     4     7     5
# 4     5     8     6

# %%
data2
# Out:
#    key1  key4  key5
# 0     1    33     8
# 1     3     4     7
# 2     7    43     8
# 3     6    45     6
# 4     5     6     7

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    33     8
# 1     3     6     3     4     7
# 2     5     8     6     6     7

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  33.0   8.0
# 1     2     5     5   NaN   NaN
# 2     3     6     3   4.0   7.0
# 3     4     7     5   NaN   NaN
# 4     5     8     6   6.0   7.0

# %%
pd.merge(data1,data2,how='right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    33     8
# 1     3   6.0   3.0     4     7
# 2     7   NaN   NaN    43     8
# 3     6   NaN   NaN    45     6
# 4     5   8.0   6.0     6     7

# %%
pd.merge(data1,data2,how = 'outer',on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  33.0   8.0
# 1     2   5.0   5.0   NaN   NaN
# 2     3   6.0   3.0   4.0   7.0
# 3     4   7.0   5.0   NaN   NaN
# 4     5   8.0   6.0   6.0   7.0
# 5     7   NaN   NaN  43.0   8.0
# 6     6   NaN   NaN  45.0   6.0

# %%
data1 = pd.DataFrame({'key1':[1,2,4,5,6],
                      'key2':[4,5,6,7,8],
                      'key3':[3,4,5,6,6]},
                     index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame({'key11':[1,2,4,5,6],
                      'key22':[4,5,6,7,8],
                      'key33':[3,4,5,6,6]
},index=['a','b','h','i','j']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
data2
# Out:
#    key11  key22  key33
# a      1      4      3
# b      2      5      4
# h      4      6      5
# i      5      7      6
# j      6      8      6

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='left')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3    1.0    4.0    3.0
# b     2     5     4    2.0    5.0    4.0
# c     4     6     5    NaN    NaN    NaN
# d     5     7     6    NaN    NaN    NaN
# e     6     8     6    NaN    NaN    NaN

# %%
data1.join(data2,how='inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# a     1     4     3      1      4      3
# b     2     5     4      2      5      4

# %%
data1.join(data2,how='outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   1.0   4.0   3.0    1.0    4.0    3.0
# b   2.0   5.0   4.0    2.0    5.0    4.0
# c   4.0   6.0   5.0    NaN    NaN    NaN
# d   5.0   7.0   6.0    NaN    NaN    NaN
# e   6.0   8.0   6.0    NaN    NaN    NaN
# h   NaN   NaN   NaN    4.0    6.0    5.0
# i   NaN   NaN   NaN    5.0    7.0    6.0
# j   NaN   NaN   NaN    6.0    8.0    6.0

# %%
data1.join(data2,how='cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      1     4     3      1      4      3
# 1      1     4     3      2      5      4
# 2      1     4     3      4      6      5
# 3      1     4     3      5      7      6
# 4      1     4     3      6      8      6
# 5      2     5     4      1      4      3
# 6      2     5     4      2      5      4
# 7      2     5     4      4      6      5
# 8      2     5     4      5      7      6
# 9      2     5     4      6      8      6
# 10     4     6     5      1      4      3
# 11     4     6     5      2      5      4
# 12     4     6     5      4      6      5
# 13     4     6     5      5      7      6
# 14     4     6     5      6      8      6
# 15     5     7     6      1      4      3
# 16     5     7     6      2      5      4
# 17     5     7     6      4      6      5
# 18     5     7     6      5      7      6
# 19     5     7     6      6      8      6
# 20     6     8     6      1      4      3
# ...

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df['New_column']=df['Fare'].apply( lambda x: x*90)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
def Cat_Fare(x):
    if x< 10:
        return "cheap"
    elif x>=10 and x<30:
        return "mid"
    else :
        return "high"

# %%
df['new_column_1']=df['Fare'].apply(Cat_Fare)

# %%
df
# Out:
#                                                   Name  Survived  Pclass  \
# 0                              Braund, Mr. Owen Harris         0       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                               Heikkinen, Miss. Laina         1       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                             Allen, Mr. William Henry         0       3
# ..                                                 ...       ...     ...
# 886                              Montvila, Rev. Juozas         0       2
# 887                       Graham, Miss. Margaret Edith         1       1
# 888           Johnston, Miss. Catherine Helen "Carrie"         0       3
# 889                              Behr, Mr. Karl Howell         1       1
# 890                                Dooley, Mr. Patrick         0       3
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# # lecture change

# %%
data = {'key1':[1,2,3,4,5],
       'key2':[3,4,5,6,7],
       'key3':['aditya','india','pandas','python','golden']}

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#    key1  key2    key3
# 0     1     3  aditya
# 1     2     4   india
# 2     3     5  pandas
# 3     4     6  python
# 4     5     7  golden

# %%
df.set_index('key1',inplace=True)

# %%
df
# Out:
#       key2    key3
# key1
# 1        3  aditya
# 2        4   india
# 3        5  pandas
# 4        6  python
# 5        7  golden

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    key1  key2    key3
# 0     1     3  aditya
# 1     2     4   india
# 2     3     5  pandas
# 3     4     6  python
# 4     5     7  golden

# %%
data = {'key1':[1,2,3,4,5],
       'key2':[3,4,5,6,7],
       'key3':['aditya','india','pandas','python','golden']}
df1 = pd.DataFrame(data,index=['a','b','c','d','e'])

# %%
df1
# Out:
#    key1  key2    key3
# a     1     3  aditya
# b     2     4   india
# c     3     5  pandas
# d     4     6  python
# e     5     7  golden

# %%
df1.reindex(['e','d','c','b','a'])
# Out:
#    key1  key2    key3
# e     5     7  golden
# d     4     6  python
# c     3     5  pandas
# b     2     4   india
# a     1     3  aditya

# %%
df1
# Out:
#    key1  key2    key3
# a     1     3  aditya
# b     2     4   india
# c     3     5  pandas
# d     4     6  python
# e     5     7  golden

# %%
df1.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001D7115CC8C0>

# %%
for i,j in df1.iterrows():
    print(j)
# Out:
# key1         1
# key2         3
# key3    aditya
# Name: a, dtype: object
# key1        2
# key2        4
# key3    india
# Name: b, dtype: object
# key1         3
# key2         5
# key3    pandas
# Name: c, dtype: object
# key1         4
# key2         6
# key3    python
# Name: d, dtype: object
# key1         5
# key2         7
# key3    golden
# Name: e, dtype: object

# %%
df1
# Out:
#    key1  key2    key3
# a     1     3  aditya
# b     2     4   india
# c     3     5  pandas
# d     4     6  python
# e     5     7  golden

# %%
list(df1['key1'])
# Out:
# [1, 2, 3, 4, 5]

# %%
[i for i in df1['key1']]
# Out:
# [1, 2, 3, 4, 5]

# %%
df1
# Out:
#    key1  key2    key3
# a     1     3  aditya
# b     2     4   india
# c     3     5  pandas
# d     4     6  python
# e     5     7  golden

# %%
def test(x):
    return x.sum()
df1.apply(test)
# Out:
# key1                               15
# key2                               25
# key3    adityaindiapandaspythongolden
# dtype: object

# %%
df2 = df1[['key1','key2']]

# %%
df2
# Out:
#    key1  key2
# a     1     3
# b     2     4
# c     3     5
# d     4     6
# e     5     7

# %%
df2.applymap(lambda x: x*x)
# Out:
#    key1  key2
# a     1     9
# b     4    16
# c     9    25
# d    16    36
# e    25    49

# %%
df1.sort_values('key3')
# Out:
#    key1  key2    key3
# a     1     3  aditya
# e     5     7  golden
# b     2     4   india
# c     3     5  pandas
# d     4     6  python

# %%
df1.sort_values('key3',ascending=False)
# Out:
#    key1  key2    key3
# d     4     6  python
# c     3     5  pandas
# b     2     4   india
# e     5     7  golden
# a     1     3  aditya

# %% [markdown]
# ### Python windows Funtion

# %%
df = pd.DataFrame({'a':[1,3,5,7,9]})

# %%
df
# Out:
#    a
# 0  1
# 1  3
# 2  5
# 3  7
# 4  9

# %%
df['a'].rolling(window=1).sum()
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    7.0
# 4    9.0
# Name: a, dtype: float64

# %%
df['a'].rolling(window=2).sum()
# Out:
# 0     NaN
# 1     4.0
# 2     8.0
# 3    12.0
# 4    16.0
# Name: a, dtype: float64

# %%
df['a'].rolling(window=2).mean()
# Out:
# 0    NaN
# 1    2.0
# 2    4.0
# 3    6.0
# 4    8.0
# Name: a, dtype: float64

# %%
df['a'].cumsum()
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: a, dtype: int64

# %% [markdown]
# #Python Pandas - Date Functionality

# %%
date = pd.date_range(start='01-01-2001',end='02-02-2001')

# %%
date
# Out:
# DatetimeIndex(['2001-01-01', '2001-01-02', '2001-01-03', '2001-01-04',
#                '2001-01-05', '2001-01-06', '2001-01-07', '2001-01-08',
#                '2001-01-09', '2001-01-10', '2001-01-11', '2001-01-12',
#                '2001-01-13', '2001-01-14', '2001-01-15', '2001-01-16',
#                '2001-01-17', '2001-01-18', '2001-01-19', '2001-01-20',
#                '2001-01-21', '2001-01-22', '2001-01-23', '2001-01-24',
#                '2001-01-25', '2001-01-26', '2001-01-27', '2001-01-28',
#                '2001-01-29', '2001-01-30', '2001-01-31', '2001-02-01',
#                '2001-02-02'],
#               dtype='datetime64[ns]', freq='D')

# %%
df_date = pd.DataFrame({'date':date})

# %%
df_date.head()
# Out:
#         date
# 0 2001-01-01
# 1 2001-01-02
# 2 2001-01-03
# 3 2001-01-04
# 4 2001-01-05

# %%
df_date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
df_date['year']= df_date['date'].dt.year

# %%
df_date.head()
# Out:
#         date  year
# 0 2001-01-01  2001
# 1 2001-01-02  2001
# 2 2001-01-03  2001
# 3 2001-01-04  2001
# 4 2001-01-05  2001

# %%
df_date['month']=df_date['date'].dt.month

# %%
df_date.head()
# Out:
#         date  year  month
# 0 2001-01-01  2001      1
# 1 2001-01-02  2001      1
# 2 2001-01-03  2001      1
# 3 2001-01-04  2001      1
# 4 2001-01-05  2001      1

# %% [markdown]
# #Python Pandas –visualisation

# %%
d = pd.Series([2,3,4,5,6,7])

# %%
d
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
d.plot()
# Out:
# <Axes: >

# %%
gdt =pd.DataFrame({'a':[3,4,5,6,7],
                  'b':[4,5,3,5,6]})

# %%
gdt
# Out:
#    a  b
# 0  3  4
# 1  4  5
# 2  5  3
# 3  6  5
# 4  7  6

# %%
gdt.plot()
# Out:
# <Axes: >

# %%
gdt.plot(x='a', y='b')
# Out:
# <Axes: xlabel='a'>

# %%
gdt.plot.scatter(x= 'a',y='b')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %%
d
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# 5    7
# dtype: int64

# %%
d.plot.pie()
# Out:
# <Axes: >

# %% [markdown]
# # The end of Pandas
